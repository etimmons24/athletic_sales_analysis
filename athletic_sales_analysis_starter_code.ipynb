# %%
# Import Libraries and Dependencies
import pandas as pd
from datetime import datetime, date, time, timezone

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020_df = pd.read_csv("Resources/athletic_sales_2020.csv")

athletic_sales_2021_df = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
athletic_sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
athletic_sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
athletic_sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
athletic_sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
athletic_sales_2020__2021_df = athletic_sales_2020_df.join(athletic_sales_2021_df, how='inner', lsuffix='_2020', rsuffix='_2021')
athletic_sales_2020__2021_df.reset_index(inplace=True)

# %%
athletic_sales_2020__2021_df.head(10)
# Out:
#    index retailer_2020  retailer_id_2020 invoice_date_2020 region_2020  \
# 0      0   Foot Locker           1185732            1/1/20   Northeast
# 1      1   Foot Locker           1185732            1/1/20   Northeast
# 2      2   Foot Locker           1185732            1/1/20   Northeast
# 3      3   Foot Locker           1185732            1/1/20   Northeast
# 4      4   Foot Locker           1185732            1/1/20   Northeast
# 5      5   Foot Locker           1185732            1/1/20   Northeast
# 6      6     West Gear           1128299            1/2/20   Northeast
# 7      7     West Gear           1128299            1/2/20   Northeast
# 8      8   Foot Locker           1185732            1/2/20   Northeast
# 9      9     West Gear           1128299            1/2/20   Northeast
#
#      state_2020     city_2020             product_2020  price_per_unit_2020  \
# 0      New York      New York    Men's Street Footwear                   50
# ...

# %%
# Check if any values are null.
athletic_sales_2020__2021_df.dropna(how="any")
# Out:
#       index retailer_2020  retailer_id_2020 invoice_date_2020 region_2020  \
# 0         0   Foot Locker           1185732            1/1/20   Northeast
# 1         1   Foot Locker           1185732            1/1/20   Northeast
# 2         2   Foot Locker           1185732            1/1/20   Northeast
# 3         3   Foot Locker           1185732            1/1/20   Northeast
# 4         4   Foot Locker           1185732            1/1/20   Northeast
# ...     ...           ...               ...               ...         ...
# 1292   1292     West Gear           1128299          12/30/20        West
# 1293   1293     West Gear           1128299          12/30/20        West
# 1294   1294        Kohl's           1189833          12/30/20     Midwest
# 1295   1295        Kohl's           1189833          12/30/20     Midwest
# 1296   1296     West Gear           1128299          12/30/20        West
#
#         state_2020      city_2020             product_2020  \
# ...

# %%
# Check the data type of each column
athletic_sales_2020__2021_df.dtypes
# Out:
# index                      int64
# retailer_2020             object
# retailer_id_2020           int64
# invoice_date_2020         object
# region_2020               object
# state_2020                object
# city_2020                 object
# product_2020              object
# price_per_unit_2020        int64
# units_sold_2020            int64
# total_sales_2020           int64
# operating_profit_2020    float64
# sales_method_2020         object
# retailer_2021             object
# retailer_id_2021           int64
# invoice_date_2021         object
# region_2021               object
# state_2021                object
# city_2021                 object
# product_2021              object
# price_per_unit_2021        int64
# units_sold_2021            int64
# total_sales_2021           int64
# operating_profit_2021    float64
# sales_method_2021         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
athletic_sales_2020__2021_df['invoice_date_2020'] = pd.to_datetime(athletic_sales_2020__2021_df['invoice_date_2020'], format="%d/%m/%Y")
athletic_sales_2020__2021_df['invoice_date_2021'] = pd.to_datetime(athletic_sales_2020__2021_df['invoice_date_2021'], format="%d/%m/%Y")

# %%
# Confirm that the "invoice_date" data type has been changed.
athletic_sales_2020__2021_df['invoice_date_2020'].head()
# Out:
# 0   2020-01-01
# 1   2020-01-01
# 2   2020-01-01
# 3   2020-01-01
# 4   2020-01-01
# Name: invoice_date_2020, dtype: datetime64[ns]

# %%
athletic_sales_2020__2021_df['invoice_date_2021'].head()
# Out:
# 0   2021-01-01
# 1   2021-01-01
# 2   2021-01-01
# 3   2021-01-01
# 4   2021-01-01
# Name: invoice_date_2021, dtype: datetime64[ns]

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".




# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.


# Rename the "units_sold" column to "Total_Products_Sold"


# Show the top 5 results.

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in ascending order on "Total Sales".

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
